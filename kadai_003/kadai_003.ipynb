# %% [markdown]
# Step1.
# NumPyをインポートするコードを記述する
# Step2.
# AとBの行列を格納する多次元配列のコードを記述する
# Step3.
# 行列の積の計算をするコードを記述する
# Step4.
# Step3.の計算結果を表示するコードを記述する
# Step5.
# 行列の要素の最大値を求めるコードを記述する

# %%
import numpy as np


array_a = np.array([[0, 1], [2, 2],[4, 5]])
array_a

array_b = np.array([[0, 1,2,3], [4,5,6,7]])
array_b

keisan=np.dot(array_a, array_b)
keisan
keisan.max()
# Out:
# array([[ 4,  5,  6,  7],
#        [ 8, 12, 16, 20],
#        [20, 29, 38, 47]])
