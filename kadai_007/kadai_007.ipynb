# %% [markdown]
# キー	ディクショナリに入れる文字列
# mon	晴れ
# tue	雨
# wed	晴れ
# thu	晴れ
# fri	曇り
# sat	曇りのち雨
# sun	雷雨

# %%
「array」という名前のリストを以下の内容で作成してください。

リストの順序	リストに入れる文字列
0	月曜日は晴れです
1	火曜日は雨です
2	水曜日は晴れです
3	木曜日は晴れです
4	金曜日は曇りです
5	土曜日は曇りのち雨です
6	日曜日は雷雨です

# %%
array=["月曜日は晴れです","火曜日は雨です","水曜日は晴れです","木曜日は晴れです","金曜日は曇りです","土曜日は曇りのち雨です","日曜日は雷雨です"]
print(array)
# Out:
# ['月曜日は晴れです', '火曜日は雨です', '水曜日は晴れです', '木曜日は晴れです', '金曜日は曇りです', '土曜日は曇りのち雨です', '日曜日は雷雨です']

# %%
dictionary={"mon": "晴れ","tue": "雨", "wed": "晴れ", "wed": "晴れ", "thu": "晴れ", "fri": "曇り", "sat": "曇りのち雨", "sun": "雷雨"}
print(dictionary)
print(dictionary["mon"])
# Out:
# 晴れ
