# %%
class Human:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def printinfo(self):
        print("名前:", self.name)
        print("年齢:", self.age)


# Humanクラスのインスタンスを変数に代入
person = Human("山田花子", 20)

# メソッドを呼び出して情報を表示
person.printinfo()
# Out:
# 名前: 山田花子
# 年齢: 20
